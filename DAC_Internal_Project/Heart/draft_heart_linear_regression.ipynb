# %%
# Import our libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
from sklearn import linear_model

# %%
df = pd.read_csv('/Users/nikgurunathan/dac/My-DAC-Curriculum/DAC_Internal_Project/Heart/Heart_cleaned.csv')
df
# Out:
#                  State     Sex  ... CovidPos  CalculatedBMI
# 0              alabama  female  ...       no      27.353965
# 1              alabama  female  ...       no      26.578125
# 2              alabama  female  ...      yes      25.761694
# 3              alabama  female  ...       no      23.324151
# 4              alabama  female  ...       no      21.899469
# ...                ...     ...  ...      ...            ...
# 444757  virgin islands  female  ...      yes      25.656566
# 444758  virgin islands  female  ...       no      28.723183
# 444759  virgin islands  female  ...       no      20.358819
# 444760  virgin islands    male  ...      yes      32.506196
# 444761  virgin islands    male  ...       no      22.498583
#
# [444762 rows x 41 columns]

# %%
# %matplotlib inline
plt.xlabel('OriginalBMI')
plt.ylabel('CalculatedBMI')
plt.scatter(df['BMI'], df['CalculatedBMI'], color= 'red', marker= '+')
